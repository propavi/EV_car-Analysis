# %%
import pandas as pd
import matplotlib.pyplot as plt
ev = pd.read_csv("EVCars.csv")
ev
# Out:
#     region    category                      parameter  mode powertrain  year  \
# 0    World  Historical                       EV stock  Cars       PHEV  2010
# 1    World  Historical                       EV sales  Cars       PHEV  2010
# 2    World  Historical           Oil displacement Mbd  Cars         EV  2010
# 3    World  Historical  Oil displacement, million lge  Cars         EV  2010
# 4    World  Historical                       EV sales  Cars        BEV  2010
# ..     ...         ...                            ...   ...        ...   ...
# 149  World  Historical                       EV stock  Cars        BEV  2023
# 150  World  Historical                       EV sales  Cars        BEV  2023
# 151  World  Historical                       EV stock  Cars       FCEV  2023
# 152  World  Historical                       EV sales  Cars       PHEV  2023
# 153  World  Historical                       EV stock  Cars       PHEV  2023
#
# ...

# %%
ev_stock = ev[ev["parameter"] == "EV stock"]
ev_stock
# Out:
#     region    category parameter  mode powertrain  year      unit       value
# 0    World  Historical  EV stock  Cars       PHEV  2010  Vehicles       400.0
# 5    World  Historical  EV stock  Cars        BEV  2010  Vehicles     20000.0
# 7    World  Historical  EV stock  Cars       FCEV  2010  Vehicles        45.0
# 14   World  Historical  EV stock  Cars       FCEV  2011  Vehicles        83.0
# 16   World  Historical  EV stock  Cars        BEV  2011  Vehicles     58000.0
# 21   World  Historical  EV stock  Cars       PHEV  2011  Vehicles      9500.0
# 22   World  Historical  EV stock  Cars       PHEV  2012  Vehicles     70000.0
# 27   World  Historical  EV stock  Cars        BEV  2012  Vehicles    120000.0
# 29   World  Historical  EV stock  Cars       FCEV  2012  Vehicles       110.0
# 36   World  Historical  EV stock  Cars       FCEV  2013  Vehicles       140.0
# 38   World  Historical  EV stock  Cars        BEV  2013  Vehicles    230000.0
# ...

# %%
ev_stock_grouped = ev_stock.groupby("year")["value"].sum()
ev_stock_grouped.plot(x="year",y="value",kind="bar")
plt.xlabel("year")
plt.ylabel("EV Stock")
plt.show()

# %%
ev_sales = ev[ev["parameter"] == "EV sales"]
ev_sales
# Out:
#     region    category parameter  mode powertrain  year      unit      value
# 1    World  Historical  EV sales  Cars       PHEV  2010  Vehicles      450.0
# 4    World  Historical  EV sales  Cars        BEV  2010  Vehicles     7000.0
# 6    World  Historical  EV sales  Cars       FCEV  2010  Vehicles       29.0
# 15   World  Historical  EV sales  Cars       FCEV  2011  Vehicles       38.0
# 17   World  Historical  EV sales  Cars        BEV  2011  Vehicles    40000.0
# 20   World  Historical  EV sales  Cars       PHEV  2011  Vehicles     9000.0
# 23   World  Historical  EV sales  Cars       PHEV  2012  Vehicles    61000.0
# 26   World  Historical  EV sales  Cars        BEV  2012  Vehicles    59000.0
# 28   World  Historical  EV sales  Cars       FCEV  2012  Vehicles       30.0
# 37   World  Historical  EV sales  Cars       FCEV  2013  Vehicles       46.0
# 39   World  Historical  EV sales  Cars        BEV  2013  Vehicles   110000.0
# ...

# %%
ev_sales_grouped = ev_sales.groupby("year")["value"].sum()
ev_sales_grouped
ev_sales_grouped.plot(x="year",y="value",kind="bar")
plt.xlabel("year")
plt.ylabel("EV Sales")
plt.show()

# %%
ev_stock_grouped = ev_stock.groupby("year")["value"].sum().reset_index()
ev_sales_grouped = ev_sales.groupby("year")["value"].sum().reset_index()
merged_df = pd.merge(ev_stock_grouped,ev_sales_grouped,on = "year")
bar_width = 0.35
r1 = range(len(merged_df["year"]))
r2 = [x + bar_width for x in r1]
plt.figure(figsize=(10,6))
plt.bar(r1, merged_df['value_x'], color='b', width=bar_width,label = 'EV Stock')
plt.bar(r2, merged_df['value_y'], color='r', width=bar_width, label='EV Sales')
plt.xlabel('Year')
plt.xticks([r + bar_width/2 for r in range(len(merged_df['year']))], merged_df['year'],rotation = 45)
plt.ylabel('Number of Vehicles')
plt.title('EV Stocks and Sales per Year')
plt.legend()
plt.show()

# %%
ev_electricity = ev[ev["parameter"] == "Electricity demand"]
ev_electricity
# Out:
#     region    category           parameter  mode powertrain  year unit  \
# 10   World  Historical  Electricity demand  Cars         EV  2010  GWh
# 11   World  Historical  Electricity demand  Cars         EV  2011  GWh
# 32   World  Historical  Electricity demand  Cars         EV  2012  GWh
# 33   World  Historical  Electricity demand  Cars         EV  2013  GWh
# 54   World  Historical  Electricity demand  Cars         EV  2014  GWh
# 55   World  Historical  Electricity demand  Cars         EV  2015  GWh
# 76   World  Historical  Electricity demand  Cars         EV  2016  GWh
# 77   World  Historical  Electricity demand  Cars         EV  2017  GWh
# 98   World  Historical  Electricity demand  Cars         EV  2018  GWh
# 99   World  Historical  Electricity demand  Cars         EV  2019  GWh
# 120  World  Historical  Electricity demand  Cars         EV  2020  GWh
# 121  World  Historical  Electricity demand  Cars         EV  2021  GWh
# ...

# %%
ev_electricity.plot(x="year",y ="value",kind="line",color="b",label = "Electricity")
plt.xlabel("year")
plt.ylabel("GigaWatt Hour")
plt.title("Electricity Usage in GWH per year")
plt.show()

# %%
ev_barrels_per_year = ev[ev["parameter"] == "Oil displacement Mbd"]
ev_barrels_per_year["value"] = ev_barrels_per_year["value"] * 1000000 * 365
ev_barrels_per_year
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6040\2037696413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_barrels_per_year["value"] = ev_barrels_per_year["value"] * 1000000 * 365
#     region    category             parameter  mode powertrain  year  \
# 2    World  Historical  Oil displacement Mbd  Cars         EV  2010
# 18   World  Historical  Oil displacement Mbd  Cars         EV  2011
# 24   World  Historical  Oil displacement Mbd  Cars         EV  2012
# 40   World  Historical  Oil displacement Mbd  Cars         EV  2013
# 46   World  Historical  Oil displacement Mbd  Cars         EV  2014
# 64   World  Historical  Oil displacement Mbd  Cars         EV  2015
# ...
